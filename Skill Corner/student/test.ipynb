# %%
from skillcorner.client import SkillcornerClient

import pandas as pd

import numpy as np

import os

secret_password = os.getenv("mdp_skillcorner")
client = SkillcornerClient(username = "Nathan.talbot@etu.uca.fr", password= secret_password)

# %%
physical_data_json = client.get_physical(params = {"data_version" : 3, 'competition_edition': 549, "group_by" : "team",
                                                                     "possession" : ["tip", "otip"]})

# %%
pd.DataFrame(compet.competition.tolist())
# Out:
#      id      area                                name  gender age_group
# 0    51  CONMEBOL                        Copa America    male     adult
# 1   147       AFC                    Champions League    male     adult
# 2   311       ARG                      Copa Argentina    male     adult
# 3    70       ARG        Primera Division - 1st Phase    male     adult
# 4   319       BOL                                LFPB    male     adult
# 5   308       BRA                      Copa do Brasil    male     adult
# 6   239       BRA                           Mineiro 1    male     adult
# 7    77       BRA                             Série A    male     adult
# 8    80       BRA                             Série B    male     adult
# 9   203       CAN             Canadian Premier League    male     adult
# 10   57       CHI                    Primera Division    male     adult
# 11   47       CHN                        Super League    male     adult
# 12  100       COL                        Liga Dimayor    male     adult
# 13  159  CONCACAF                    Champions League    male     adult
# 14   36  CONCACAF                            Gold Cup    male     adult
# 15  234  CONCACAF              Gold Cup Qualification    male     adult
# 16  109  CONMEBOL                   Copa Libertadores    male     adult
# 17  110  CONMEBOL                   Copa Sudamericana    male     adult
# 18  138       ECU                            Liga Pro    male     adult
# 19   20       INT              Friendly International    male     adult
# 20  149       INT                     Club Friendlies    male     adult
# 21  123       INT        Women Friendly International  female     adult
# 22   87       JPN                           J1 League    male     adult
# 23  240       JPN                           J2 League    male     adult
# 24  194       KOR                          K League 1    male     adult
# 25  222       LVA                            Virsliga    male     adult
# 26  124       NOR                         Eliteserien    male     adult
# 27  228       NOR                          Toppserien  female     adult
# 28  140       PAR                Division Profesional    male     adult
# 29  139       PER                    Primera Division    male     adult
# 30   90       SWE                         Allsvenskan    male     adult
# 31  229       SWE                      Damallsvenskan  female     adult
# 32   95       URU                    Primera Division    male     adult
# 33   60       USA                 Major League Soccer    male     adult
# 34  190       USA                        MLS Next Pro    male     adult
# 35  126       USA                                NWSL  female     adult
# 36  154       USA                  NWSL Challenge Cup  female     adult
# 37  191       USA                    USL Championship    male     adult
# 38   68       BRA                  Paulista, Serie A1    male     adult
# 39  226       INT        U16 National Team Friendlies    male       U16
# 40  335       BRA                 Supercopa do Brasil    male     adult
# 41  337  CONCACAF            Women's U17 Championship  female       U17
# 42  168       BRA                           Carioca 1    male     adult
# 43  150       INT   Torneio Internacional Algarve U17    male       U17
# 44  341       BRA                            Gaúcho 1    male     adult
# 45  342  CONCACAF                    Women's Gold Cup  female     adult
# 46  343  CONCACAF      Road to W Gold Cup - Play-Offs  female     adult
# 47  344  CONMEBOL                 Recopa Sudamericana    male     adult
# 48  345       INT        Football Federations Cup U16    male       U16
# 49  346  CONCACAF                         Leagues Cup    male     adult
# 50  373       AFC          West Asia Championship U23    male       U23
# 51  161       INT        U19 National Team Friendlies    male       U19
# 52  374       INT  U19 National Team Friendlies Women  female     adult
# 53  375       INT  U17 National Team Friendlies Women  female       U17
# 54  186       INT                     SheBelieves Cup  female     adult
# 55  376       ARG        Primera Division - 2nd Phase    male     adult
# 56    2      UEFA               European Championship    male     adult
# 57  377       RSA                         Nedbank Cup    male     adult
# 58  378      UEFA                          Baltic Cup    male     adult

# %%
pd.DataFrame(data).iloc[10000:50000]
# Out:
#        frame    timestamp  period  \
# 10000  10000  00:12:21.00     1.0
# 10001  10001  00:12:21.10     1.0
# 10002  10002  00:12:21.20     1.0
# 10003  10003  00:12:21.30     1.0
# 10004  10004  00:12:21.40     1.0
# ...      ...          ...     ...
# 49995  49995  01:18:17.50     2.0
# 49996  49996  01:18:17.60     2.0
# 49997  49997  01:18:17.70     2.0
# 49998  49998  01:18:17.80     2.0
# 49999  49999  01:18:17.90     2.0
#
#                                                ball_data  \
# 10000  {'x': 29.16, 'y': -28.85, 'z': 0.17, 'is_detec...
# 10001  {'x': 29.54, 'y': -29.11, 'z': 0.19, 'is_detec...
# 10002  {'x': 29.91, 'y': -29.36, 'z': 0.17, 'is_detec...
# 10003  {'x': 30.4, 'y': -29.55, 'z': 0.13, 'is_detect...
# 10004  {'x': 30.79, 'y': -29.88, 'z': 0.09, 'is_detec...
# ...                                                  ...
# 49995  {'x': 43.43, 'y': -8.44, 'z': 3.5, 'is_detecte...
# 49996  {'x': 42.98, 'y': -9.55, 'z': 2.7, 'is_detecte...
# 49997  {'x': 42.5, 'y': -10.55, 'z': 1.94, 'is_detect...
# 49998  {'x': 42.03, 'y': -11.46, 'z': 1.36, 'is_detec...
# 49999  {'x': 41.55, 'y': -12.24, 'z': 1.19, 'is_detec...
#
#                                         possession  \
# 10000  {'player_id': 187090, 'group': 'away team'}
# 10001  {'player_id': 187090, 'group': 'away team'}
# 10002  {'player_id': 187090, 'group': 'away team'}
# 10003  {'player_id': 187090, 'group': 'away team'}
# 10004  {'player_id': 187090, 'group': 'away team'}
# ...                                            ...
# 49995    {'player_id': None, 'group': 'away team'}
# 49996    {'player_id': None, 'group': 'away team'}
# 49997    {'player_id': None, 'group': 'away team'}
# 49998    {'player_id': None, 'group': 'away team'}
# 49999    {'player_id': None, 'group': 'away team'}
#
#                                 image_corners_projection  \
# 10000  {'x_top_left': 12.32, 'y_top_left': 39.0, 'x_b...
# 10001  {'x_top_left': 13.19, 'y_top_left': 39.0, 'x_b...
# 10002  {'x_top_left': 14.8, 'y_top_left': 39.0, 'x_bo...
# 10003  {'x_top_left': 16.16, 'y_top_left': 39.0, 'x_b...
# 10004  {'x_top_left': 17.77, 'y_top_left': 39.0, 'x_b...
# ...                                                  ...
# 49995  {'x_top_left': 57.62, 'y_top_left': 39.0, 'x_b...
# 49996  {'x_top_left': 56.67, 'y_top_left': 39.0, 'x_b...
# 49997  {'x_top_left': 55.8, 'y_top_left': 39.0, 'x_bo...
# 49998  {'x_top_left': 54.78, 'y_top_left': 39.0, 'x_b...
# 49999  {'x_top_left': 53.96, 'y_top_left': 39.0, 'x_b...
#
#                                              player_data
# 10000  [{'x': -29.75, 'y': -1.64, 'player_id': 645956...
# 10001  [{'x': -29.64, 'y': -1.65, 'player_id': 645956...
# 10002  [{'x': -29.54, 'y': -1.66, 'player_id': 645956...
# 10003  [{'x': -29.44, 'y': -1.67, 'player_id': 645956...
# 10004  [{'x': -29.33, 'y': -1.67, 'player_id': 645956...
# ...                                                  ...
# 49995  [{'x': -31.28, 'y': 3.36, 'player_id': 13159, ...
# 49996  [{'x': -31.31, 'y': 3.26, 'player_id': 13159, ...
# 49997  [{'x': -31.35, 'y': 3.16, 'player_id': 13159, ...
# 49998  [{'x': -31.41, 'y': 3.06, 'player_id': 13159, ...
# 49999  [{'x': -31.48, 'y': 2.96, 'player_id': 13159, ...
#
# [40000 rows x 7 columns]

# %%
a = pd.DataFrame(np.arange(10).reshape(5, 2))
a.to_excel(f"..\\..\\Tableau métriques\\student\\2022_2023\\Skill Corner\\metrique_physical.xlsx", header = True, index = True)
