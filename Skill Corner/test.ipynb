# %%
from skillcorner.client import SkillcornerClient

import pandas as pd

import numpy as np

import os

secret_password = os.getenv("mdp_skillcorner")
client = SkillcornerClient(username = "Nathan.talbot@etu.uca.fr", password= secret_password)

# %%
i = 0
liste_dico = [{"comp_id" : 549,
                "ranking" : ["AJ Auxerre", "Angers SCO", "AS Saint-Étienne", "Rodez Aveyron", "Paris FC", "SM Caen", "Stade Lavallois Mayenne FC",
           "Amiens Sporting Club", "En Avant de Guingamp", "Pau FC", "Grenoble Foot 38", "Girondins de Bordeaux", "SC Bastia",
           "FC Annecy", "AC Ajaccio", "Dunkerque", "ES Troyes AC", "US Quevilly-Rouen", "US Concarneau", "Valenciennes FC"],
           "annee" : "2023_2024"},
           {"comp_id" : 393,
                "ranking" : ["Le Havre AC", "FC Metz", "Girondins de Bordeaux", "SC Bastia", "SM Caen", "En Avant de Guingamp", "Paris FC",
           "AS Saint-Étienne", "FC Sochaux-Montbéliard", "Grenoble Foot 38", "US Quevilly-Rouen", "Amiens Sporting Club", "Pau FC",
           "Rodez Aveyron", "Stade Lavallois Mayenne FC", "Valenciennes FC", "FC Annecy", "Dijon FCO", "Nîmes Olympique", "Chamois Niortais FC"],
           "annee" : "2022_2023"},
           {"comp_id" : 243,
                "ranking" : ["Toulouse FC", "AC Ajaccio", "AJ Auxerre", "Paris FC", "FC Sochaux-Montbéliard", "En Avant de Guingamp",
                             "SM Caen", "Le Havre AC", "Nîmes Olympique", "Pau FC", "Dijon FCO", "SC Bastia", "Chamois Niortais FC", 
                             "Amiens Sporting Club", "Grenoble Foot 38", "Valenciennes FC", "Rodez Aveyron", "US Quevilly-Rouen",
                             "Dunkerque", "AS Nancy-Lorraine"],
           "annee" : "2021_2022"}
           ]

dico = liste_dico[i]
running_data_json = client.get_in_possession_off_ball_runs(params = {'competition_edition': dico["comp_id"], "group_by" : "team",
        "run_type" : ["run_in_behind", "run_ahead_of_the_ball", "support_run", "pulling_wide_run", "coming_short_run", "underlap_run",
                        "overlap_run", "dropping_off_run", "pulling_half_space_run", "cross_receiver_run"]})
running_data = pd.DataFrame(running_data_json).set_index("team_name")
running_data.drop(["team_id", "third", "channel", "minutes_played_per_match", "adjusted_min_tip_per_match",
        "count_match", "count_match_failed", "count_runs_in_behind_in_sample"], inplace = True, axis = 1)
running_data = running_data.reindex(dico["ranking"])

top5 = dico["ranking"][:5]
top15 = dico["ranking"][5:]
top5_df = running_data.loc[top5]
top15_df = running_data.loc[top15]

mean_top5 = top5_df.mean(axis = 0)
mean_top15 = top15_df.mean(axis = 0)

# %%
df_final = pd.DataFrame(index = top5_df.columns)

df_final["Moyenne Top 5"] = top5_df.mean(axis = 0)
df_final["Moyenne Bottom 15"] = top15_df.mean(axis = 0)

df_final["Ratio Moyennes"] = df_final["Moyenne Top 5"]/df_final["Moyenne Bottom 15"]
df_final.loc[df_final["Ratio Moyennes"] < 1, "Ratio Moyennes"] **= -1

df_final["Ecart type Top 5"] = top5_df.std(axis = 0)
df_final["Ecart type Bottom 15"] = top15_df.std(axis = 0)

df_final["Min Top 5"] = top5_df.min(axis = 0)
df_final["Min Bottom 15"] = top15_df.min(axis = 0)

df_final["Max Top 5"] = top5_df.max(axis = 0)
df_final["Max Bottom 15"] = top15_df.max(axis = 0)

df_final.replace([np.inf, -np.inf], 0, inplace=True)
df_final.fillna(0, inplace = True)
df_final.sort_values(by = "Ratio Moyennes", inplace = True, ascending = False)
df_final
# Out:
#                                                     Moyenne Top 5  \
# count_dangerous_coming_short_runs_received_per_...          0.004
# overlap_runs_targeted_threat_per_match                      0.006
# count_pulling_wide_runs_leading_to_goal_per_match           0.002
# pulling_half_space_runs_threat_per_match                    0.010
# overlap_runs_received_threat_per_match                      0.002
# ...                                                           ...
# count_dropping_off_runs_leading_to_goal_per_match           0.000
# dropping_off_runs_targeted_threat_per_match                 0.000
# count_dangerous_dropping_off_runs_received_per_...          0.000
# pulling_half_space_runs_received_threat_per_match           0.000
# pulling_half_space_runs_targeted_threat_per_match           0.000
#
#                                                     Moyenne Bottom 15  \
# count_dangerous_coming_short_runs_received_per_...           0.000667
# overlap_runs_targeted_threat_per_match                       0.001333
# count_pulling_wide_runs_leading_to_goal_per_match            0.000667
# pulling_half_space_runs_threat_per_match                     0.003333
# overlap_runs_received_threat_per_match                       0.000667
# ...                                                               ...
# count_dropping_off_runs_leading_to_goal_per_match            0.000000
# dropping_off_runs_targeted_threat_per_match                  0.000000
# count_dangerous_dropping_off_runs_received_per_...           0.000000
# pulling_half_space_runs_received_threat_per_match            0.000000
# pulling_half_space_runs_targeted_threat_per_match            0.000000
#
#                                                     Ratio Moyennes  \
# count_dangerous_coming_short_runs_received_per_...             6.0
# overlap_runs_targeted_threat_per_match                         4.5
# count_pulling_wide_runs_leading_to_goal_per_match              3.0
# pulling_half_space_runs_threat_per_match                       3.0
# overlap_runs_received_threat_per_match                         3.0
# ...                                                            ...
# count_dropping_off_runs_leading_to_goal_per_match              0.0
# dropping_off_runs_targeted_threat_per_match                    0.0
# count_dangerous_dropping_off_runs_received_per_...             0.0
# pulling_half_space_runs_received_threat_per_match              0.0
# pulling_half_space_runs_targeted_threat_per_match              0.0
#
#                                                     Ecart type Top 5  \
# count_dangerous_coming_short_runs_received_per_...          0.005477
# overlap_runs_targeted_threat_per_match                      0.005477
# count_pulling_wide_runs_leading_to_goal_per_match           0.004472
# pulling_half_space_runs_threat_per_match                    0.000000
# overlap_runs_received_threat_per_match                      0.004472
# ...                                                              ...
# count_dropping_off_runs_leading_to_goal_per_match           0.000000
# dropping_off_runs_targeted_threat_per_match                 0.000000
# count_dangerous_dropping_off_runs_received_per_...          0.000000
# pulling_half_space_runs_received_threat_per_match           0.000000
# pulling_half_space_runs_targeted_threat_per_match           0.000000
#
#                                                     Ecart type Bottom 15  \
# count_dangerous_coming_short_runs_received_per_...              0.002582
# overlap_runs_targeted_threat_per_match                          0.003519
# count_pulling_wide_runs_leading_to_goal_per_match               0.002582
# pulling_half_space_runs_threat_per_match                        0.004880
# overlap_runs_received_threat_per_match                          0.002582
# ...                                                                  ...
# count_dropping_off_runs_leading_to_goal_per_match               0.000000
# dropping_off_runs_targeted_threat_per_match                     0.000000
# count_dangerous_dropping_off_runs_received_per_...              0.000000
# pulling_half_space_runs_received_threat_per_match               0.000000
# pulling_half_space_runs_targeted_threat_per_match               0.000000
#
#                                                     Min Top 5  Min Bottom 15  \
# count_dangerous_coming_short_runs_received_per_...       0.00            0.0
# overlap_runs_targeted_threat_per_match                   0.00            0.0
# count_pulling_wide_runs_leading_to_goal_per_match        0.00            0.0
# pulling_half_space_runs_threat_per_match                 0.01            0.0
# overlap_runs_received_threat_per_match                   0.00            0.0
# ...                                                       ...            ...
# count_dropping_off_runs_leading_to_goal_per_match        0.00            0.0
# dropping_off_runs_targeted_threat_per_match              0.00            0.0
# count_dangerous_dropping_off_runs_received_per_...       0.00            0.0
# pulling_half_space_runs_received_threat_per_match        0.00            0.0
# pulling_half_space_runs_targeted_threat_per_match        0.00            0.0
#
#                                                     Max Top 5  Max Bottom 15
# count_dangerous_coming_short_runs_received_per_...       0.01           0.01
# overlap_runs_targeted_threat_per_match                   0.01           0.01
# count_pulling_wide_runs_leading_to_goal_per_match        0.01           0.01
# pulling_half_space_runs_threat_per_match                 0.01           0.01
# overlap_runs_received_threat_per_match                   0.01           0.01
# ...                                                       ...            ...
# count_dropping_off_runs_leading_to_goal_per_match        0.00           0.00
# dropping_off_runs_targeted_threat_per_match              0.00           0.00
# count_dangerous_dropping_off_runs_received_per_...       0.00           0.00
# pulling_half_space_runs_received_threat_per_match        0.00           0.00
# pulling_half_space_runs_targeted_threat_per_match        0.00           0.00
#
# [119 rows x 9 columns]

# %%
ratio_mean = mean_top5/mean_top15
ratio_mean[ratio_mean < 1] **= -1
df_final = pd.concat([mean_top5, mean_top15, ratio_mean], axis = 1)
df_final.columns = ["Moyenne TOP 5", "Moyenne BOTTOM 15", "Ratio Moyennes"]
df_final.replace([np.inf, -np.inf], 0, inplace=True)
df_final.fillna(0, inplace = True)
df_final.sort_values(by = "Ratio Moyennes", inplace = True, ascending = False)

# %%
df_final.to_excel(f"..\\..\\Tableau métriques\\moyenne\\{dico["annee"]}\\Skill Corner\\moyenne_running.xlsx")
